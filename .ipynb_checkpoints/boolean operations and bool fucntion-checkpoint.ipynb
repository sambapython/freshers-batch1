# %%
# the expression returns a boolean value(True/False) boolean expression
a=1000
b=5000
print(a==b)
# Out:
# False

# %%
# the expression returns a boolean value(True/False) boolean expression
a=5000
b=5000
print(a==b)
# Out:
# True

# %%
# the expression returns a boolean value(True/False) boolean expression
a=5000
b=5000
print(a == b, a is b)# == value, is id..
# Out:
# True False

# %%
# the expression returns a boolean value(True/False) boolean expression
a=5000
b=a
print(a == b, a is b)# == compares value attribute, is compares id attribute of an object..
# Out:
# True True

# %%
a=1000
b=2000
print(a>b)
# Out:
# False

# %%
a=5
b=4
print(a>b)
# Out:
# True

# %%
a=10
b=6
a>b
# Out:
# True

# %%
a="10"
b="6"
a>b
# Out:
# False

# %%
a="ant"
b="apple"
a>b
# Out:
# False

# %%
# apple, ant, bat, orange, animal
# arange the above in order.. alphabetical order..
# animal, ant, apple, bat, orange
print("animal"<"ant")
# Out:
# True

# %%
# apple, ant, bat, orange, animal
# arange the above in order.. alphabetical order..
# animal, ant, apple, bat, orange
print("apple"<"ant")
# Out:
# False

# %%
# apple, ant, bat, orange, ANIMAL
# arange the above in order.. alphabetical order..
print("animal"=="ANIMAL")
# Out:
# False

# %%
ord("i") # the ord functino returns an  ascii number of given character
# Out:
# 105

# %%
ord("t")
# Out:
# 116

# %%
"a">"A"
# Out:
# True

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
print({1,2,3,4}>{2,4,5,6})
# Out:
# False

# %%
print({1,2,3,4}<{2,4,5,6})
# Out:
# False

# %%
[1,2,3,4]==[1,2,3,4]
# Out:
# True

# %%
[1,2,3,4]==[1,5,2,3,4]
# Out:
# False

# %%
[1,2,3,4]>[1,5,2,3,4]
# Out:
# False

# %%
[1,2,3,4]>[1,1,2,3,4]
# Out:
# True

# %%
(1,2,3,4)>(1,1,2,3,4)
# Out:
# True

# %%
[1,2,3,4]==[1,3,2,4]
# Out:
# False

# %%
{1,2,3,4}=={1,3,2,4}
# Out:
# True

# %%
[1,2,3,4]==[1,3,2,4]
# Out:
# False

# %%
(1,2,3,4)==(1,3,2,4)
# Out:
# False

# %%
# list and tuple are sequential data types
k=[1,2,3,4]
print(k)
# Out:
# [1, 2, 3, 4]

# %%
# list and tuple are sequential data types
k=(1,2,3,4)
print(k)
# Out:
# (1, 2, 3, 4)

# %%
# set int NOT sequential data types
k={1,2,3,4}
print(k)
# Out:
# {1, 2, 3, 4}

# %%
# set int NOT sequential data types. Unordered
k={10,20,30,40}
print(k)
# Out:
# {40, 10, 20, 30}

# %%
k=[10,20,30,40]
print(k[0], k[1])
# Out:
# 10 20

# %%
# set int NOT sequential data types. Unordered
k={10,20,30,40}
print(k[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # set int NOT sequential data types. Unordered
#       2 k={10,20,30,40}
# ----> 3 print(k[1])
#
# TypeError: 'set' object is not subscriptable

# %%
k={1,3,2,4}
m={1,4,2,3}
print(k==m)
# Out:
# True

# %%
k={1,3,2,4}
m={1,4,2,3,5}
print(k==m)
# Out:
# False

# %%
# subset, superset?
print({1,3,2}<{20,30,40,50})
# Out:
# False

# %%
# subset, superset?
print({1,3,2}<{1,2,20,30,40,50})
# Out:
# False

# %%
# subset, superset?
print({1,3,2}<{1,2,20,30,40,50,3})
# Out:
# True

# %%
# subset, superset?
print({1,3,2}>{3,2})
# Out:
# True

# %%
bool(12) # True, False
# Out:
# True

# %%
bool(-12) # True, False
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("python")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool("0")
# Out:
# True

# %%
bool([1,2,3,4])
# Out:
# True

# %%
bool([0])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool((0,))
# Out:
# True

# %%
bool({0})
# Out:
# True

# %%
# number: 0-> False,  other numbers: True
#non-number datatypes: empty: False, if it has an elements: True
