# %%
print(1000+2000/100*2)
# Out:
# 1040.0

# %%
2000/100
# Out:
# 20.0

# %%
20*2
# Out:
# 40

# %%
1000+40
# Out:
# 1040

# %%
print(1000+2000/(100*2))
# Out:
# 1010.0

# %%
100*2
# Out:
# 200

# %%
2000/200
# Out:
# 10.0

# %%
1000+10
# Out:
# 1010

# %%
print(1000/200/10/2)
# Out:
# 0.25

# %%
print(5/10/2)
# Out:
# 0.25

# %%
print(0.5/2)
# Out:
# 0.25

# %%
print(1000/200/10/2) # left to Right

# %%
print((1000/(200/(10/2)))) # left to Right
# Out:
# 25.0

# %%
10/2
# Out:
# 5.0

# %%
200/5
# Out:
# 40.0

# %%
1000/40
# Out:
# 25.0
