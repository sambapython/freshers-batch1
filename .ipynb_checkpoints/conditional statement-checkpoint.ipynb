# %%
a=1000
b=2000
print("a is big")
print("b is big")
# Out:
# a is big
# b is big

# %%
a=1000
b=200
print("a is big")
print("b is big")
# Out:
# a is big
# b is big

# %%
a=1000
b=200
print("a is big")
if False:
    print("b is big")
# Out:
# a is big

# %%
a=1000
b=2000
if False:
    print("a is big")# indentation
print("b is big")
# Out:
# b is big

# %%
print("started")
a=1000
b=2000
if True:
    print("a is big")# indentation
else:
    print("b is big")
print("ENDED")
# Out:
# started
# a is big
# ENDED

# %%
print("started")
a=1000
b=2000
if a<b:#(1000<2000): True
    print("a is big")
else:
    print("b is big")
print("ENDED")
# Out:
# started
# a is big
# ENDED

# %%
print("started")
a=1000
b=2000
if a<b:#(1000<2000): True
    print("b is big")
else:
    print("a is big")
print("ENDED")
# Out:
# started
# b is big
# ENDED

# %%
print("started")
a=1000
b=2000
if a>b:#1000>2000: False
    print("b is big")
else:
    print("a is big")
print("ENDED")
# Out:
# started
# a is big
# ENDED

# %%
print("started")
a=1000
if a>0:#1000>0: True
    print("-VE")
else:
    print("+VE")
print("ENDED")
# Out:
# started
# -VE
# ENDED

# %%
print("started")
a=1000
if a>0:#1000>0: True
    print("+VE")
else:
    print("-VE")
print("ENDED")
# Out:
# started
# +VE
# ENDED

# %%
print("started")
a=-20
if a>0:#-20>0: False
    print("+VE")
else:
    print("-VE")
print("ENDED")
# Out:
# started
# -VE
# ENDED

# %%
# check whether the given string has atlast one char or not.
data = input("enter string")
print(data, len(data))
# Out:
# enter string python
# python 6

# %%
# check whether the given string has atlast one char or not.
data = input("enter string")
print(data, len(data))
# Out:
# enter string hyderabad
# hyderabad 9

# %%
# check whether the given string has atlast one char or not.
data = input("enter string")
print(data, len(data))
# Out:
# enter string
#  0

# %%
# empty string,   valid string
data = input("enter string")
if len(data)==0:
    print("empty string")
else:
    print("valid string")
# Out:
# enter string qwer23
# valid string

# %%
# empty string,   valid string
data = input("enter string")
if len(data)==0:
    print("empty string")
else:
    print("valid string")
# Out:
# enter string
# empty string

# %%
memory_kb=input("Enter memory in KB:")
memory_mb=memory_kb/1024
# Out:
# Enter memory in KB: 3468
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 memory_kb=input("Enter memory in KB:")
# ----> 2 memory_mb=memory_kb/1024
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"3468"/1024
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 "3468"/1024
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
memory_kb=input("Enter memory in KB:")
memory_mb=int(memory_kb)/1024
# Out:
# Enter memory in KB: 3468

# %%
print(memory_mb)
# Out:
# 3.38671875

# %%
#Take a memory from the user and Convert kilobytes (KB) to megabytes (MB
memory_kb=input("Enter memory in KB:")
memory_mb=int(memory_kb)/1024
print(memory_mb)

# %%
# number postiive or negative
a=input("Enter number:")
if a>0:
    print("+VE")
else:
    print("-VE")
# Out:
# Enter number: 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # number postiive or negative
#       2 a=input("Enter number:")
# ----> 3 if a>0:
#       4     print("+VE")
#       5 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# number postiive or negative
a=input("Enter number:")
a=int(a)
if a>0:
    print("+VE")
else:
    print("-VE")
# Out:
# Enter number: 10
# +VE

# %%
# number postiive or negative
a=input("Enter number:")
a=int(a)
if a>0:
    print("+VE")
else:
    print("-VE")
# Out:
# Enter number: -12
# -VE

# %%
# number postiive or negative
a=input("Enter number:")
a=int(a)
if a>0:
    print("+VE")
else:
    print("-VE")
# Out:
# Enter number: 0
# -VE

# %%
0>0
# Out:
# False

# %%
0<0
# Out:
# False

# %%
# number postiive or negative
a=input("Enter number:")
a=int(a)
if a==0:#0==0: True
    print("ZERO")
if a>0:#0>0: False
    print("+VE")
else:
    print("-VE")
# Out:
# Enter number: 0
# ZERO
# -VE

# %%
# number postiive or negative
a=input("Enter number:")
a=int(a)
if a==0:#0==0: True
    print("ZERO")
else:
    if a>0:#0>0: False
        print("+VE")
    else:
        print("-VE")
print("DONE")
# Out:
# Enter number: 0
# ZERO
# DONE

# %%
# number postiive or negative
a=input("Enter number:")
a=int(a)
if a==0:#10==0: False
    print("ZERO")
else:
    if a>0:#10>0: True
        print("+VE")
    else:
        print("-VE")
print("DONE")
# Out:
# Enter number: 10
# +VE
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD")
# Out:
# Operations:
# 1.ADD

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
print(option)
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 3
# 3

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
print(option)
if option==1:
    print(a+b)
if option==2:
    print(a-b)
if option==3:
    print(a*b)
if option==4:
    print(a/b)
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# 2

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option==1:#"2"==1
    print(a+b)
if option==2:#"2"==2
    print(a-b)
if option==3:
    print(a*b)
if option==4:
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# DONE

# %%
"2"==2
# Out:
# False

# %%
"2"=="2"
# Out:
# True

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"2"=="1": False
    print(a+b)
if option=="2":#"2"=="2": True
    print(a-b)
if option=="3":#"2"=="3": False
    print(a*b)
if option=="4"#"2"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# -10
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"3"=="1": False
    print(a+b)
if option=="2":#"3"=="2": False
    print(a-b)
if option=="3":#"3"=="3": True
    print(a*b)
if option=="4":#"3"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 3
# 200
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"2"=="1": False
    print(a+b)
if option=="2":#"2"=="2": True
    print(a-b)
if option=="2":#"2"=="2": True
    print(a*b)
if option=="4":#"3"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# -10
# 200
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"1"=="1": True
    print(a+b)
if option=="2":#"2"=="2": True
    print(a-b)
if option=="3":#"2"=="2": True
    print(a*b)
if option=="4":#"3"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 1
# 30
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"1"=="1": True
    print(a+b)
if option=="2":#"2"=="2": True
    print(a-b)
if option=="3":#"2"=="2": False
    print(a*b)
if option=="4":#"3"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# -10
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"1"=="1": False
    print(a+b)
if option=="2":#"2"=="2": False
    print(a-b)
if option=="3":#"2"=="2": True
    print(a*b)
if option=="4":#"3"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 3
# 200
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"6"=="1": False
    print(a+b)
if option=="2":#"6"=="2": False
    print(a-b)
if option=="3":#"6"=="3": False
    print(a*b)
if option=="4":#"6"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 4
# 0.5
# DONE

# %%
True
# Out:
# True

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"6"=="1": False
    print(a+b)
if option=="2":#"6"=="2": False
    print(a-b)
if option=="3":#"6"=="3": False
    print(a*b)
if option=="4":#"6"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 6
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"2"=="1": False
    print(a+b)
elif option=="2":#"2"=="2": True
    print(a-b)
elif option=="3":
    print(a*b)
elif option=="4":
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# -10
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"2"=="1": False
    print(a+b)
elif option=="2":#"2"=="2": True
    print(a-b)
elif option=="3":
    print(a*b)
elif option=="2":
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 2
# -10
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"4"=="1": False
    print(a+b)
elif option=="2":#"4"=="2": False
    print(a-b)
elif option=="3":#"4"=="3": False
    print(a*b)
elif option=="2":#"4"=="2": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 4
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"4"=="1": False
    print(a+b)
elif option=="2":#"4"=="2": False
    print(a-b)
elif option=="3":#"4"=="3": False
    print(a*b)
elif option=="4":#"4"=="4": True
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 4
# 0.5
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"6"=="1": False
    print(a+b)
elif option=="2":#"6"=="2": False
    print(a-b)
elif option=="3":#"6"=="3": False
    print(a*b)
elif option=="4":#"6"=="4": False
    print(a/b)
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 6
# DONE

# %%
# menu driven program
a=10
b=20
print("Operations:\n1.ADD\n2.SUB\n3.MUL\n4.DIV")
option=input("Enter an option:")
if option=="1":#"6"=="1": False
    print(a+b)
elif option=="2":#"6"=="2": False
    print(a-b)
elif option=="3":#"6"=="3": False
    print(a*b)
elif option=="4":#"6"=="4": False
    print(a/b)
else:
    print("WRONG OPTION")
print("DONE")
# Out:
# Operations:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# Enter an option: 6
# WRONG OPTION
# DONE
