# %%
s="hydera"
print(s[0], s[-6])
# Out:
# h h

# %%
s="hydera"
print(s[1], s[-5])
# Out:
# y y

# %%
s="hydera"
print(s[2], s[-4])
# Out:
# d d

# %%
s="hydera"
print(s[5], s[-1])
# Out:
# a a

# %%
s="hydera"
print(s[0], s[-0])
# Out:
# h h

# %%
s="hydera"
print(s[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 s="hydera"
# ----> 2 print(s[6])
#
# IndexError: string index out of range

# %%
s="hydera"
print(s[-7])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 s="hydera"
# ----> 2 print(s[-7])
#
# IndexError: string index out of range

# %%
s="hydera"
print(s[0],s[1],s[2])
# Out:
# h y d

# %%
s="hydera"
print(s[0],s[1],s[2],s[3],s[4])
# Out:
# h y d e r

# %%
s="hydera"
print(s[0:4])# include starting index, exclude the ending index
# Out:
# hyde

# %%
s="hydera"
print(s[0:5])# include starting index, exclude the ending index
# Out:
# hyder

# %%
s="hydera"
print(s[1:5])# include starting index, exclude the ending index
# Out:
# yder

# %%
s="hydera"
print(s[2:5])# include starting index, exclude the ending index : step value; +1
# Out:
# der

# %%
s="hydera"
print(s[5:2]) # step value +1

# %%
# The direction decides by the third indexing or step index
s="hydera"
print(s[0:5:1])# the default step value is +1
# Out:
# hyder

# %%
# The direction decides by the third indexing or step index
s="hydera"
print(s[0:5:2])# +2: direction: towards right or towards end of the string..
# Out:
# hdr

# %%
s="hydera"
print(s[5:2])

# %%
s="hydera"
print(s[3:1])

# %%
s="hydera"
print(s[3:1:-1])
# Out:
# ed

# %%
s="hydera"
print(s[-5:-1])
# Out:
# yder

# %%
s="hyderabad"
print(s[2:4])
# Out:
# de

# %%
s="hyderabad"
print(s[:4])# +1
# Out:
# hyde

# %%
s="hyderabad"
print(s[:4:-2])
# Out:
# db

# %%
s="hyderabad"
print(s[:2:-1])
# Out:
# dabare

# %%
s="hyderabad"
print(s[:])
# Out:
# hyderabad

# %%
s="hyderabad"
print(s[::2]) # start index: 0, end index..
# Out:
# hdrbd

# %%
s="hyderabad"
print(s[::-2]) # start index: -1, end inde: begining
# Out:
# dbrdh

# %%
s="hyderabad"
print(s[::-1]) # start index: -1, end inde: begining
# Out:
# dabaredyh
