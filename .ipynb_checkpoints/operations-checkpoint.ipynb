# %%
max([1,2,3,4])
#
# Out:
# 4

# %%
max(["10","2","3","4"])
# Out:
# '4'

# %%
max(["10","2","3",4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 max(["10","2","3",4])
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
a=10
b=20
print(a>b)
# Out:
# False

# %%
a=10
b=12.34
a>b
# Out:
# False

# %%
max([1,2.3,4.5,6])
# Out:
# 6

# %%
a=10
b=1+2j
a>b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a=10
#       2 b=1+2j
# ----> 3 a>b
#
# TypeError: '>' not supported between instances of 'int' and 'complex'

# %%
max([1,2.3,1+2j])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 max([1,2.3,1+2j])
#
# TypeError: '>' not supported between instances of 'complex' and 'float'

# %%
# +,-,*,/,%,**,//
#>,<,>=,<=,==,!=,not,is,in,and,or

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
#int:  float,complex, str, list, tuple, set, dictionary 
a=10
b=12.34
print(a+b)
# Out:
# 22.34

# %%
#int:  float,complex, str, list, tuple, set, dictionary 
a=10
b=1+2j
print(a+b)
# Out:
# (11+2j)

# %%
# internal typecasting
a=10
print(a, type(a))
b=float(a)# external type casting
print(b, type(b))
# Out:
# 10 <class 'int'>
# 10.0 <class 'float'>

# %%
a=10
print(a, type(a))
b=complex(a)
print(b, type(b))
# Out:
# 10 <class 'int'>
# (10+0j) <class 'complex'>

# %%
a=10
b="20"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 a=10
#       2 b="20"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a="10"
b="20"
print(a+b)
# Out:
# 1020

# %%
a=10
b="20"
print(str(a)+b)# concatenation
# Out:
# 1020

# %%
a=10
b="20"
print(a+int(b))# summation
# Out:
# 30

# %%
a=1.2
b=2.3
print(a+b)
# Out:
# 3.5

# %%
a=10+2j
b=2+3j
print(a+b)
# Out:
# (12+5j)

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a="10"
b="20"
print(a+b)
# Out:
# 1020

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3]
b=[4,5,6]
res=[]
for i,j in zip(a,b):
    res.append(i+j)
print(res)
# Out:
# [5, 7, 9]

# %%
import numpy as np
ar1=np.array([1,2,3])
ar2=np.array([4,5,6])
print(ar1+ar2)
# Out:
# [5 7 9]

# %%
import os
print(os.__file__)
# Out:
# C:\Users\samba\miniconda3\Lib\os.py

# %%
b=10
a=[1,2,3,4]
print(b+a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 b=10
#       2 a=[1,2,3,4]
# ----> 3 print(b+a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
a=(1,2,3,4)
b=(5,6,7)
print(a+b)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
a=[1,2,3,4]
b=[5,6,7,8]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a=(1,2,3,4)
b=[1,2,3,4]
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a=(1,2,3,4)
#       2 b=[1,2,3,4]
# ----> 3 print(a+b)
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
a="123"
b=[1,2,3,4]
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 a="123"
#       2 b=[1,2,3,4]
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "list") to str

# %%
a="123"
b=(1,2,3,4)
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 a="123"
#       2 b=(1,2,3,4)
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
a="123"
b=(1,2,3,4)
print(tuple(a)+b)
# Out:
# ('1', '2', '3', 1, 2, 3, 4)

# %%
a="123"
b=(1,2,3,4)
print(a+str(b))
# Out:
# 123(1, 2, 3, 4)

# %%
a="1234"
b=tuple(a)
print(b)
# Out:
# ('1', '2', '3', '4')

# %%
a=123
b=tuple(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 a=123
# ----> 2 b=tuple(a)
#
# TypeError: 'int' object is not iterable

# %%
a=123
a=str(a)
b=tuple(a)
print(b)
# Out:
# ('1', '2', '3')

# %%
a={1,2,3,4}
b={1,3,2,4}
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 a={1,2,3,4}
#       2 b={1,3,2,4}
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a={1,2,3}
b={4,5,6}
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 a={1,2,3}
#       2 b={4,5,6}
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a={1,2,3}
b={4,5,6}
print(list(a)+list(b))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a={1,2,3}
b={4,5,6}
print(set(list(a)+list(b)))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a=1000
b=2000
print(a+b)
a=12.34
b=34.56
print(a+b)
# Out:
# 3000
# 46.900000000000006

# %%
a=10
b=2
print(a/b)
# Out:
# 5.0

# %%
a=10
b=3
print(a/b)
# Out:
# 3.3333333333333335

# %%
a=10
b=3
print(a//b)
# Out:
# 3

# %%
a=10.34
b=3
print(a//b)
# Out:
# 3.0

# %%
a=10.34
b=3
print(a/b)
# Out:
# 3.4466666666666668

# %%
a=10.34
b=3
res=a/b
print(round(res,2))
# Out:
# 3.45

# %%
a=10.34
b=3
res=a/b
print(round(res,3))
# Out:
# 3.447

# %%
a=20
b=5
print(a/b)
print(a%b)
# Out:
# 4.0
# 0

# %%
a=21
b=5
print(a/b)
print(a%b)
# Out:
# 4.2
# 1

# %%
print(4**2)
# Out:
# 16

# %%
print(4*2)
# Out:
# 8

# %%
print(4**3)
# Out:
# 64

# %%
print(64**0.5)
# Out:
# 8.0
